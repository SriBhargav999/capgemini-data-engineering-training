-- %%
CREATE TABLE employees (
emp_id INT PRIMARY KEY,
emp_name VARCHAR(50),
manager_id INT,
dept_id INT
);
INSERT INTO employees (emp_id, emp_name, manager_id, dept_id) VALUES
(1, 'Karthik', NULL, 1),
(2, 'Ajay', 1, 1),
(3, 'Vijay', 1, 2),
(4, 'Vinay', 2, 2),
(5, 'Meena', 3, 3),
(6, 'Veer', NULL, 4),
(7, 'Keerthi', 4, 5),
(8, 'Priya', 4, 5);

-- Table: departments
CREATE TABLE departments (
dept_id INT PRIMARY KEY,
dept_name VARCHAR(50)
);

INSERT INTO departments (dept_id, dept_name) VALUES
(1, 'HR'),
(2, 'IT'),
(3, 'Finance'),
(4, 'Marketing'),
(5, 'Sales');

-- Table: projects
CREATE TABLE projects (
project_id INT PRIMARY KEY,
project_name VARCHAR(50),
emp_id INT
);

INSERT INTO projects (project_id, project_name, emp_id) VALUES
(1, 'Project A', 1),
(2, 'Project B', 2),
(3, 'Project C', 3),
(4, 'Project D', 4),
(5, 'Project E', 5);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>8</td><td>8</td></tr></tbody></table></div>
-- <style scoped>
-- ...

-- %%
SELECT * FROM employees;
SELECT * FROM departments;
SELECT * FROM projects
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>manager_id</th><th>dept_id</th></tr></thead><tbody><tr><td>1</td><td>Karthik</td><td>null</td><td>1</td></tr><tr><td>2</td><td>Ajay</td><td>1</td><td>1</td></tr><tr><td>3</td><td>Vijay</td><td>1</td><td>2</td></tr><tr><td>4</td><td>Vinay</td><td>2</td><td>2</td></tr><tr><td>5</td><td>Meena</td><td>3</td><td>3</td></tr><tr><td>6</td><td>Veer</td><td>null</td><td>4</td></tr><tr><td>7</td><td>Keerthi</td><td>4</td><td>5</td></tr><tr><td>8</td><td>Priya</td><td>4</td><td>5</td></tr></tbody></table></div>
-- <style scoped>
--   .table-result-container {
-- ...

-- %%
-- names of employees and their corresponding managers even employees without managers are included
SELECT e.emp_name, m.emp_name AS manager_name 
FROM employees e 
LEFT JOIN employees m ON e.manager_id = m.emp_id;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>manager_name</th></tr></thead><tbody><tr><td>Karthik</td><td>null</td></tr><tr><td>Ajay</td><td>Karthik</td></tr><tr><td>Vijay</td><td>Karthik</td></tr><tr><td>Vinay</td><td>Ajay</td></tr><tr><td>Meena</td><td>Vijay</td></tr><tr><td>Veer</td><td>null</td></tr><tr><td>Keerthi</td><td>Vinay</td></tr><tr><td>Priya</td><td>Vinay</td></tr></tbody></table></div>

-- %%
-- employees and their corresponding departments even if they don't belong to any department
SELECT e.emp_name, d.dept_name
FROM employees e
LEFT JOIN departments d ON e.dept_id=d.dept_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Karthik</td><td>HR</td></tr><tr><td>Ajay</td><td>HR</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Veer</td><td>Marketing</td></tr><tr><td>Keerthi</td><td>Sales</td></tr><tr><td>Priya</td><td>Sales</td></tr></tbody></table></div>

-- %%
-- names of employees who report to a manager, along with their manager's name
SELECT e.emp_name, m.emp_name AS manager_name 
FROM employees e
JOIN employees m ON e.manager_id=m.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>manager_name</th></tr></thead><tbody><tr><td>Vijay</td><td>Karthik</td></tr><tr><td>Vinay</td><td>Ajay</td></tr><tr><td>Meena</td><td>Vijay</td></tr><tr><td>Priya</td><td>Vinay</td></tr><tr><td>Ajay</td><td>Karthik</td></tr><tr><td>Keerthi</td><td>Vinay</td></tr></tbody></table></div>

-- %%
-- list of employees who do not belong to any department
SELECT e.emp_name
FROM employees e
LEFT JOIN departments d ON e.dept_id=d.dept_id
WHERE d.dept_id IS NULL
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th></tr></thead><tbody></tbody></table></div>

-- %%
-- names of employees and the projects they are assigned to
SELECT e.emp_name, coalesce(p.project_name, "NULL") AS project_name
FROM employees e 
LEFT Join projects p ON e.emp_id=p.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_name</th></tr></thead><tbody><tr><td>Karthik</td><td>Project A</td></tr><tr><td>Ajay</td><td>Project B</td></tr><tr><td>Vijay</td><td>Project C</td></tr><tr><td>Vinay</td><td>Project D</td></tr><tr><td>Meena</td><td>Project E</td></tr><tr><td>Veer</td><td>NULL</td></tr><tr><td>Keerthi</td><td>NULL</td></tr><tr><td>Priya</td><td>NULL</td></tr></tbody></table></div>

-- %%
-- employees who have completed at least one project, showing their names and the project names
SELECT e.emp_name, p.project_name, COUNT(p.project_id) AS num_projects
FROM employees e 
JOIN projects p ON e.emp_id=p.emp_id
WHERE p.project_id >0
GROUP BY e.emp_name, p.project_name
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_name</th><th>num_projects</th></tr></thead><tbody><tr><td>Karthik</td><td>Project A</td><td>1</td></tr><tr><td>Ajay</td><td>Project B</td><td>1</td></tr><tr><td>Vinay</td><td>Project D</td><td>1</td></tr><tr><td>Vijay</td><td>Project C</td><td>1</td></tr><tr><td>Meena</td><td>Project E</td><td>1</td></tr></tbody></table></div>

-- %%
--names of employees and their projects, ensuring that no project is omitted even if an employee is not assigned to it
SELECT e.emp_name, p.project_name
FROM employee e
FULL JOIN projects p ON e.emp_id=p.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_name</th></tr></thead><tbody><tr><td>Ajay</td><td>Project E</td></tr><tr><td>Karthik</td><td>Project A</td></tr><tr><td>Veer</td><td>Project C</td></tr><tr><td>Pratik</td><td>Project B</td></tr><tr><td>Vijay</td><td>null</td></tr><tr><td>Veena</td><td>null</td></tr><tr><td>Priya</td><td>Project D</td></tr><tr><td>Meena</td><td>null</td></tr></tbody></table></div>

-- %%
-- names of employees and their corresponding department names
SELECT e.emp_name, d.dept_name
FROM employees e 
LEFT JOIN departments d ON e.dept_id=d.dept_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Karthik</td><td>HR</td></tr><tr><td>Ajay</td><td>HR</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Veer</td><td>Marketing</td></tr><tr><td>Keerthi</td><td>Sales</td></tr><tr><td>Priya</td><td>Sales</td></tr></tbody></table></div>

-- %%
-- departments and employees, ensuring that departments with no employees are included
SELECT d.dept_name, e.emp_name
FROM departments d
LEFT JOIN employees e ON d.dept_id=e.dept_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_name</th><th>emp_name</th></tr></thead><tbody><tr><td>HR</td><td>Ajay</td></tr><tr><td>IT</td><td>Vinay</td></tr><tr><td>Finance</td><td>Meena</td></tr><tr><td>Marketing</td><td>Veer</td></tr><tr><td>Sales</td><td>Priya</td></tr><tr><td>HR</td><td>Karthik</td></tr><tr><td>IT</td><td>Vijay</td></tr><tr><td>Sales</td><td>Keerthi</td></tr></tbody></table></div>

-- %%
-- names of employees and their department names
SELECT e.emp_name, d.dept_name
FROM employees e 
FULL JOIN departments d ON e.dept_id=d.dept_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th></tr></thead><tbody><tr><td>Keerthi</td><td>Sales</td></tr><tr><td>Priya</td><td>Sales</td></tr><tr><td>Karthik</td><td>HR</td></tr><tr><td>Ajay</td><td>HR</td></tr><tr><td>Meena</td><td>Finance</td></tr><tr><td>Vijay</td><td>IT</td></tr><tr><td>Vinay</td><td>IT</td></tr><tr><td>Veer</td><td>Marketing</td></tr></tbody></table></div>

-- %%
-- employees who have not completed any project
SELECT e.emp_name,p.project_name 
FROM employees e 
LEFT JOIN projects p ON e.emp_id=p.emp_id
WHERE p.project_id IS NULL
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_name</th></tr></thead><tbody><tr><td>Veer</td><td>null</td></tr><tr><td>Keerthi</td><td>null</td></tr><tr><td>Priya</td><td>null</td></tr></tbody></table></div>

-- %%
-- employees who have both a manager and at least one project
SELECT e.emp_name, m.emp_name, p.project_name
FROM employees e 
JOIN employees m ON e.manager_id=m.emp_id
JOIN projects p ON e.emp_id=p.emp_id
WHERE p.project_name IS NOT NULL
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>emp_name</th><th>project_name</th></tr></thead><tbody><tr><td>Ajay</td><td>Karthik</td><td>Project B</td></tr><tr><td>Vijay</td><td>Karthik</td><td>Project C</td></tr><tr><td>Vinay</td><td>Ajay</td><td>Project D</td></tr><tr><td>Meena</td><td>Vijay</td><td>Project E</td></tr></tbody></table></div>

-- %%
-- employees who belong to multiple departments, showing the employee's name and the department names
SELECT e.emp_name, de.dept_name as num_departments
FROM employees e 
JOIN employees d ON e.emp_id=d.emp_id
JOIN departments de ON e.dept_id=de.dept_id
WHERE e.emp_id IN (
  SELECT e.emp_id
  FROM employees e
  GROUP BY e.emp_id
  HAVING COUNT(e.dept_id)>1
)
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>num_departments</th></tr></thead><tbody></tbody></table></div>

-- %%
-- names of all departments and employees, ensuring that even if a department has no employees
SELECT d.dept_name, e.emp_name
FROM departments d
LEFT JOIN employees e ON d.dept_id=e.dept_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_name</th><th>emp_name</th></tr></thead><tbody><tr><td>HR</td><td>Ajay</td></tr><tr><td>IT</td><td>Vinay</td></tr><tr><td>Finance</td><td>Meena</td></tr><tr><td>Marketing</td><td>Veer</td></tr><tr><td>Sales</td><td>Priya</td></tr><tr><td>HR</td><td>Karthik</td></tr><tr><td>IT</td><td>Vijay</td></tr><tr><td>Sales</td><td>Keerthi</td></tr></tbody></table></div>

-- %%
-- employees who have worked on at least one project and do not belong to a department, listing their name and project details
SELECT e.emp_name, p.project_name
FROM employees e 
JOIN projects p ON e.emp_id = p.emp_id
WHERE e.dept_id IS NULL and p.project_id IS NOT NULL
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>project_name</th></tr></thead><tbody></tbody></table></div>

-- %%
-- employees and their managers, displaying only those employees who report to a manager
SELECT e.emp_name, m.emp_name as manager_name
FROM employees e
JOIN employees m ON e.manager_id=m.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>manager_name</th></tr></thead><tbody><tr><td>Vijay</td><td>Karthik</td></tr><tr><td>Vinay</td><td>Ajay</td></tr><tr><td>Meena</td><td>Vijay</td></tr><tr><td>Priya</td><td>Vinay</td></tr><tr><td>Ajay</td><td>Karthik</td></tr><tr><td>Keerthi</td><td>Vinay</td></tr></tbody></table></div>

-- %%
-- names of departments and the number of employees in each department, including departments that have no employees
SELECT d.dept_name, COUNT(e.emp_id) AS employee_count
FROM departments d
JOIN employees e ON d.dept_id=e.dept_id 
GROUP BY d.dept_name
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_name</th><th>employee_count</th></tr></thead><tbody><tr><td>Sales</td><td>2</td></tr><tr><td>IT</td><td>2</td></tr><tr><td>HR</td><td>2</td></tr><tr><td>Finance</td><td>1</td></tr><tr><td>Marketing</td><td>1</td></tr></tbody></table></div>

-- %%
-- names of all employees and their respective department and project assignments, including employees who are not assigned to a project or department
SELECT e.emp_name, d.dept_name, p.project_name 
FROM employees e
JOIN departments d ON e.dept_id=d.dept_id
FULL JOIN projects p ON e.emp_id=p.emp_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_name</th><th>dept_name</th><th>project_name</th></tr></thead><tbody><tr><td>Meena</td><td>Finance</td><td>Project E</td></tr><tr><td>Karthik</td><td>HR</td><td>Project A</td></tr><tr><td>Vijay</td><td>IT</td><td>Project C</td></tr><tr><td>Ajay</td><td>HR</td><td>Project B</td></tr><tr><td>Veer</td><td>Marketing</td><td>null</td></tr><tr><td>Keerthi</td><td>Sales</td><td>null</td></tr><tr><td>Vinay</td><td>IT</td><td>Project D</td></tr><tr><td>Priya</td><td>Sales</td><td>null</td></tr></tbody></table></div>
